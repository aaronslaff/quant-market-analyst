# %%
ls -a
# Out:
# ./              .gitignore           Untitled.ipynb  models/
# ../             .ipynb_checkpoints/  apt.txt         postBuild.bash
# .Trash-1000/    .project/            code/           preBuild.bash
# .git/           Dockerfile.hermes    compose.yaml    requirements.txt
# .gitattributes  README.md            data/           variables.env

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE                                     COMMAND                  CREATED          STATUS          PORTS                                             NAMES
# cbb1a96de8ab   project-quant-market-analyst              "/entrypoint.sh tail…"   23 seconds ago   Up 23 seconds                                                     project-quant-market-analyst
# 6c2575932ee4   quant-market-analyst-quant-market-agent   "hermes gateway"         26 seconds ago   Up 25 seconds   0.0.0.0:8642->8642/tcp, [::]:8642->8642/tcp       quant-market-agent
# 40c36e4dfb76   ollama/ollama:latest                      "/bin/ollama serve"      26 seconds ago   Up 25 seconds   0.0.0.0:11434->11434/tcp, [::]:11434->11434/tcp   hermes-ollama-backend
# 65a099a3a6c3   traefik:v3.6.1                            "/entrypoint.sh trae…"   3 hours ago      Up 3 hours      80/tcp, 127.0.0.1:10000->10000/tcp                workbench-proxy

# %%
# !hermes
# Out:
# /bin/bash: line 1: hermes: command not found

# %%
# !hermes --help
# Out:
# /bin/bash: line 1: hermes: command not found
